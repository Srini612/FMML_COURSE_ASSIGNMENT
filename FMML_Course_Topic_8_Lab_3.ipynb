# %% [markdown]
# <a href="https://colab.research.google.com/github/Srini612/FMML_COURSE_ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2023-05-04 06:08:17--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   162MB/s    in 0.4s
#
# 2023-05-04 06:08:22 (162 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 17637  1801.03460v1  We introduce MilkQA, a question answering data...    cs
# 4955   1705.07269v1  Deep Reinforcement Learning (DRL) methods have...    cs
# 34776  1802.06764v1  The words of a language are randomly replaced ...    cs
# 21593   1106.3571v2  Given a reproducing kernel Hilbert space H of ...  stat
# 6319   1611.03199v1  Recent advances in machine learning have made ...    cs
# ...             ...                                                ...   ...
# 38069   1203.6360v2  Understanding the ways in which information ac...    cs
# 5207    1201.3382v2  We consider the problem of using a factor mode...  stat
# 6323   1611.03578v1  Probabilistic Temporal Tensor Factorization (P...  stat
# 27615  1704.00763v1  Given a user's query, traditional image search...    cs
# 36401   1305.6037v1  In this paper the theory of semi-bounded ratio...    cs
#
#                                                    title  year  \
# 17637  MilkQA: a Dataset of Consumer Questions for th...  2018
# 4955   Learning to Factor Policies and Action-Value F...  2017
# 34776           Stability of items: an experimental test  2018
# 21593  ANOVA kernels and RKHS of zero mean functions ...  2011
# 6319      Low Data Drug Discovery with One-shot Learning  2016
# ...                                                  ...   ...
# 38069  You had me at hello: How phrasing affects memo...  2012
# 5207   Spike-and-Slab Sparse Coding for Unsupervised ...  2012
# 6323   Simple and Efficient Parallelization for Proba...  2016
# 27615  AMC: Attention guided Multi-modal Correlation ...  2017
# 36401  Semi-bounded Rationality: A model for decision...  2013
#
#                                                 keywords
# 17637  [introduce, answering, dedicated, questions, q...
# 4955   [reinforcement, performed, increasing, numberi...
# 34776  [corresponding, frequently, replacement, obser...
# 21593  [reproducing, functions, decompose, functions,...
# 6319   [significant, contributions, discovery, partic...
# ...                                                  ...
# 38069  [understanding, information, widespread, aware...
# 5207   [classification, resembles, inference, intract...
# 6323   [probabilistic, factorization, effective, algo...
# 27615  [traditional, according, relevance, surroundin...
# 36401  [rationality, extension, rationality, particul...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 17637    [introduce, answering, dedicated, questions, q...
# 4955     [reinforcement, performed, increasing, numberi...
# 34776    [corresponding, frequently, replacement, obser...
# 21593    [reproducing, functions, decompose, functions,...
# 6319     [significant, contributions, discovery, partic...
#                                ...
# 35877    [constraint, satisfaction, perspective, constr...
# 26849    [algorithm, supervised, segmentation, supervis...
# 22887    [theoretical, foundations, mechanisms, constru...
# 11291    [successfully, parameters, estimated, currentl...
# 39554    [autonomously, searching, hazardous, radiation...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8698 words.
# Out of those 4587 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="dfe1191f-0c38-401f-b366-38ded1688d4e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dfe1191f-0c38-401f-b366-38ded1688d4e")) {                    Plotly.newPlot(                        "dfe1191f-0c38-401f-b366-38ded1688d4e",                        [{"x":["challenging","reasonable","dedicated","originally","available","collected","challenges","particularly","elaborated","requirements","anonymized","linguistic","experimented","information","resources","thousands","backgrounds","unusually","computational","specialists","situations","annotators","brazilian","questions","portuguese","selection","motivated","convolutional","different","introduce","answering","characteristics","corporation","agricultural","decompose","representations","components","orthogonal","performed","reinforcement","algorithm","independent","considerable","dimensional","advantage","increasing","underlying","simultaneously","algorithms","functions","architectural","executing","traditionally","decomposing","compositional","outperforms","exploiting","demonstrate","analogous","improvements","composition","representation","structure","modification","languages","explicitly","nevertheless","fundamental","stability","threefold","literature","corresponding","estimated","universal","frequently","experimental","observable","replacement","comparison","supported","classical","indisputable","framework","sensitivity","reproducing","analyzing","convenient","regularization","functional","decomposition","elegantly","computing","interpolation","predictor","inferring","architecture","significantly","demonstrated","molecules","meaningful","applications","significant","particular","compounds","predictive","activities","contributions","discovery","properties","applicability","introduced","predictions","techniques","requirement","embedding","induction","important","implementation","validation","disadvantage","generally","efficient","adaptations","applicable","integrating","straightforward","technique","including","nonconvex","especially","estimation","divergence","exemplify","conjugate","bernstein","appropriate","penalties","generalized","regression","coordinate","empirical","nonsmooth","penalization","maximization","threshold","mathematical","penalized","additionally","establish","essential","knowledge","quantitative","introductory","implementing","sensitive","reasoning","accommodation","imprecise","interpretable","detecting","composable","fragments","discussing","specifying","generated","interpretation","understanding","capturing","describing","approaches","interpreting","uncertain","concludes","generation","classifiers","justification","classification","successful","classifier","exponential","perspective","theoretical","averaging","incomplete","conventional","explanations","explanation","explaining","conjecture","complexity","interpolating","substantially","likelihood","procedure","optimization","conceived","mechanism","stratified","statistical","approximation"],"y":[273,33,20,13,304,70,114,80,2,34,1,66,7,721,57,26,5,1,250,6,50,13,4,75,6,149,53,348,750,332,73,89,1,4,10,214,99,20,120,124,818,138,42,203,99,91,121,104,574,224,5,8,24,10,32,269,75,509,10,113,34,388,354,23,100,79,19,94,41,3,125,143,56,31,25,416,15,6,135,12,106,1,533,37,3,67,16,66,40,56,2,121,16,17,36,243,260,114,7,56,422,242,279,6,64,35,47,48,222,33,147,80,366,21,101,14,329,137,38,7,73,398,4,53,45,21,233,212,8,125,183,28,5,6,0,78,4,66,125,26,145,2,1,27,44,78,7,69,60,71,371,78,2,30,54,129,1,9,35,67,1,8,10,11,184,64,148,42,27,451,12,32,2,139,113,7,478,76,155,46,73,174,16,43,105,18,30,18,12,243,2,42,69,105,281,3,117,4,147,113],"type":"bar"},{"x":["challenging","reasonable","dedicated","originally","available","collected","challeng ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4587,), (4587, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8258333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Compact</span> <span style='background-color:rgba(0, 255, 0, 0.5428571428571429);'>Architecture</span> <span style=''>for</span> <span style=''>Dialogue</span> <span style='background-color:rgba(0, 255, 0, 0.7358490566037735);'>Management</span> <span style=''>Based</span> <span style=''>on</span> <span style=''>Scripts</span> <span style=''>and</span> <span style=''>Meta</span> <span style=''>Outputs</span> <br/><br/><span style=''>We</span> <span style=''>describe</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.5428571428571429);'>architecture</span> <span style=''>for</span> <span style=''>spoken</span> <span style=''>dialogue</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interfaces</span> <span style=''>to</span> <span style=''>semi</span> <span style='background-color:rgba(0, 255, 0, 0.8285714285714286);'>autonomous</span> <span style=''>systems</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transforms</span> <span style=''>speech</span> <span style=''>signals</span> <span style=''>through</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>successive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>representations</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.8857142857142857);'>linguistic</span> <span style=''>dialogue</span> <span style=''>and</span> <span style=''>domain</span> <span style='background-color:rgba(0, 255, 0, 0.40264650283553877);'>knowledge</span> <span style=''>Each</span> <span style=''>step</span> <span style=''>produces</span> <span style=''>an</span> <span style=''>output</span> <span style=''>and</span> <span style=''>a</span> <span style=''>meta</span> <span style=''>output</span> <span style='background-color:rgba(0, 255, 0, 0.3170731707317073);'>describing</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.41414141414141414);'>transformation</span> <span style=''>with</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>executable</span> <span style=''>program</span> <span style=''>in</span> <span style=''>a</span> <span style=''>simple</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>scripting</span> <span style=''>language</span> <span style=''>as</span> <span style=''>the</span> <span style=''>final</span> <span style=''>result</span> <span style=''>The</span> <span style=''>outputmeta</span> <span style=''>output</span> <span style='background-color:rgba(0, 255, 0, 0.5);'>distinction</span> <span style=''>permits</span> <span style=''>perspicuous</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>treatment</span> <span style=''>of</span> <span style=''>diverse</span> <span style=''>tasks</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.6923076923076923);'>resolving</span> <span style=''>pronouns</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correcting</span> <span style=''>user</span> <span style=''>misconceptions</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimizing</span> <span style=''>scripts</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Fast</span> <span style=''>MCMC</span> <span style=''>sampling</span> <span style=''>for</span> <span style=''>Markov</span> <span style=''>jump</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>time</span> <span style=''>Bayesian</span> <span style=''>networks</span> <br/><br/><span style=''>Markov</span> <span style=''>jump</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>processes</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>time</span> <span style=''>Bayesian</span> <span style=''>networks</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>important</span> <span style=''>classes</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dynamical</span> <span style=''>systems</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>tackle</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inferring</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unobserved</span> <span style=''>paths</span> <span style=''>in</span> <span style=''>these</span> <span style=''>models</span> <span style=''>by</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introducing</span> <span style=''>a</span> <span style=''>fast</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>auxiliary</span> <span style=''>variable</span> <span style=''>Gibbs</span> <span style=''>sampler</span> <span style=''>Our</span> <span style=''>approach</span> <span style=''>is</span> <span style=''>based</span> <span style=''>on</span> <span style=''>the</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>uniformization</span> <span style=''>and</span> <span style=''>sets</span> <span style=''>up</span> <span style=''>a</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>over</span> <span style=''>paths</span> <span style=''>by</span> <span style=''>sampling</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>set</span> <span style=''>of</span> <span style=''>virtual</span> <span style=''>jump</span> <span style=''>times</span> <span style=''>and</span> <span style=''>then</span> <span style=''>running</span> <span style=''>a</span> <span style=''>standard</span> <span style=''>hidden</span> <span style=''>Markov</span> <span style=''>model</span> <span style=''>forward</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>filtering</span> <span style=''>backward</span> <span style=''>sampling</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>over</span> <span style=''>states</span> <span style=''>at</span> <span style=''>the</span> <span style=''>set</span> <span style=''>of</span> <span style=''>extant</span> <span style=''>and</span> <span style=''>virtual</span> <span style=''>jump</span> <span style=''>times</span> <span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computational</span> <span style=''>benefits</span> <span style=''>over</span> <span style=''>a</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>Gibbs</span> <span style=''>sampler</span> <span style=''>on</span> <span style=''>a</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>continuous</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style=''>using</span> <span style=''>Max</span> <span style=''>norm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Constrained</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Optimization</span> <br/><br/><span style=''>We</span> <span style=''>suggest</span> <span style=''>using</span> <span style=''>the</span> <span style=''>max</span> <span style=''>norm</span> <span style=''>as</span> <span style=''>a</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>surrogate</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraint</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>We</span> <span style=''>show</span> <span style=''>how</span> <span style=''>this</span> <span style=''>yields</span> <span style=''>a</span> <span style=''>better</span> <span style=''>exact</span> <span style=''>cluster</span> <span style=''>recovery</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>guarantee</span> <span style=''>than</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>previously</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>suggested</span> <span style=''>nuclear</span> <span style=''>norm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relaxation</span> <span style=''>and</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>effectiveness</span> <span style=''>of</span> <span style=''>our</span> <span style=''>method</span> <span style=''>and</span> <span style=''>other</span> <span style=''>related</span> <span style=''>convex</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>relaxations</span> <span style=''>compared</span> <span style=''>to</span> <span style=''>other</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Stability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Structured</span> <span style=''>Variable</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <br/><br/><span style=''>In</span> <span style=''>variable</span> <span style=''>or</span> <span style=''>graph</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>problems</span> <span style=''>finding</span> <span style=''>a</span> <span style=''>right</span> <span style=''>sized</span> <span style=''>model</span> <span style=''>or</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>controlling</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>false</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>positives</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>notoriously</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>Recently</span> <span style=''>a</span> <span style=''>meta</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Stability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Selection</span> <span style=''>was</span> <span style=''>proposed</span> <span style=''>that</span> <span style=''>can</span> <span style=''>provide</span> <span style=''>reliable</span> <span style=''>finite</span> <span style=''>sample</span> <span style=''>control</span> <span style=''>of</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style=''>false</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>positives</span> <span style=''>Its</span> <span style=''>benefits</span> <span style=''>were</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>demonstrated</span> <span style=''>when</span> <span style=''>used</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conjunction</span> <span style=''>with</span> <span style=''>the</span> <span style=''>lasso</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>orthogonal</span> <span style=''>matching</span> <span style=''>pursuit</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>investigate</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>applicability</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>the</span> <span style=''>group</span> <span style=''>lasso</span> <span style=''>and</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>input</span> <span style=''>output</span> <span style=''>lasso</span> <span style=''>We</span> <span style=''>find</span> <span style=''>that</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stability</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>increases</span> <span style=''>the</span> <span style=''>power</span> <span style=''>of</span> <span style=''>both</span> <span style='background-color:rgba(255, 0 ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	architecture (0.08712800286841162)
# 	representation (0.13911796342775187)
# 	knowledge (0.1330225887414844)
# 	segmentation (0.07350304768734313)
# 	information (0.2585155969881678)
# 	different (0.2689135891000359)
# 	experimental (0.14915740408748657)
# 	convolutional (0.12477590534241664)
# 	detection (0.12800286841161707)
# 	recognition (0.13015417712441735)
#
# Some Statistics words are:
# 	distributions (0.12182993535554451)
# 	stochastic (0.13127797115862755)
# 	statistical (0.14321233217304824)
# 	variables (0.1427150671307807)
# 	algorithm (0.39234211834908006)
# 	estimation (0.1755345599204376)
# 	inference (0.19293883639980108)
# 	dimensional (0.1979114868224764)
# 	distribution (0.1964196916956738)
# 	regression (0.174042764793635)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.18.2.min.js"></script>                <div id="9d77c06a-4a4b-4a42-81f3-82dd98a9d64e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9d77c06a-4a4b-4a42-81f3-82dd98a9d64e")) {                    Plotly.newPlot(                        "9d77c06a-4a4b-4a42-81f3-82dd98a9d64e",                        [{"x":["challenging","reasonable","dedicated","originally","available","collected","challenges","particularly","elaborated","requirements","anonymized","linguistic","experimented","information","resources","thousands","backgrounds","unusually","computational","specialists","situations","annotators","brazilian","questions","portuguese","selection","motivated","convolutional","different","introduce","answering","characteristics","corporation","agricultural","decompose","representations","components","orthogonal","performed","reinforcement","algorithm","independent","considerable","dimensional","advantage","increasing","underlying","simultaneously","algorithms","functions","architectural","executing","traditionally","decomposing","compositional","outperforms","exploiting","demonstrate","analogous","improvements","composition","representation","structure","modification","languages","explicitly","nevertheless","fundamental","stability","threefold","literature","corresponding","estimated","universal","frequently","experimental","observable","replacement","comparison","supported","classical","indisputable","framework","sensitivity","reproducing","analyzing","convenient","regularization","functional","decomposition","elegantly","computing","interpolation","predictor","inferring","architecture","significantly","demonstrated","molecules","meaningful","applications","significant","particular","compounds","predictive","activities","contributions","discovery","properties","applicability","introduced","predictions","techniques","requirement","embedding","induction","important","implementation","validation","disadvantage","generally","efficient","adaptations","applicable","integrating","straightforward","technique","including","nonconvex","especially","estimation","divergence","exemplify","conjugate","bernstein","appropriate","penalties","generalized","regression","coordinate","empirical","nonsmooth","penalization","maximization","threshold","mathematical","penalized","additionally","establish","essential","knowledge","quantitative","introductory","implementing","sensitive","reasoning","accommodation","imprecise","interpretable","detecting","composable","fragments","discussing","specifying","generated","interpretation","understanding","capturing","describing","approaches","interpreting","uncertain","concludes","generation","classifiers","justification","classification","successful","classifier","exponential","perspective","theoretical","averaging","incomplete","conventional","explanations","explanation","explaining","conjecture","complexity","interpolating","substantially","likelihood","procedure","optimization","conceived","mechanism","stratified","statistical","approximation","asymptotic","introducing","formulation","consideration","carefully","computation","connectivity","functionality","similarity","compression","dissimilarity","performance","supervised","asymmetric","effectiveness","representative","symmetric","automatic","surveillance","asynchronous","hierarchical","interactions","furthermore","relationship","recognition","detection","euclidean","databases","invertibility","fingerprint","resultant","protection","nonlinear","mitigating","representational","correlated","proposition","correlation","transforms","transformation","biometric","templates","resilient","practical","benchmark","statistics","invertible","inversion","guarantees","capability","enforcement","automatically","verifiable","population ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	bernstein
# 	normality
# 	nonparanormal
# 	submodels
# 	overfitted
# 	metabolic
# 	changepoints
# 	frequentist
# 	tractably
# 	electroencephalography
# 	tractographies
# 	tractography
# 	tibshirani
# 	smoothers
# 	convexification
# 	contractive
# 	diagnosed
# 	physician
# 	purchases
# 	oftentimes
# Some words which never appear in Statistics papers:
# 	experimented
# 	backgrounds
# 	specialists
# 	threefold
# 	proposition
# 	eigenmodes
# 	hallucination
# 	diversification
# 	paraphrase
# 	accomplishing
# 	captioned
# 	mastering
# 	rotationally
# 	starcraft
# 	nonmonotonic
# 	vertebral
# 	permission
# 	phonological
# 	assembled
# 	avoidance

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.079102133817779e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7808333333333334
